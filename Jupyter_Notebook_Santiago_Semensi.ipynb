# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Santiago Semensi**
#
# Industrial Designer looking forward to become a Data Scientist

# %% [markdown]
# *I am interested in data science because I love to learn new tools, and this is a field of study that is always growing. I also like that is so related with machine learning and AI, subjects that I think are key for the present and future of technology.*

# %% [markdown]
# ## Import Math library and calculate the area of a circle

# %%
# Importing math Library
import math
# Define function
def circle_area(r):
    return (math.pi*r**2)

# Get the area of a circle of radius 5
print ("The area of a circle of radius 5 is:")
circle_area(5)
# Out:
# The area of a circle of radius 5 is:
# 78.53981633974483

# %% [markdown]
#  - Horizontal rule:
# ***
#  - Image:
#
# ![Circle-Area-with-Measurements.png](attachment:7ab0a195-17f3-4174-86c7-90c3a88a6be9.png)
#
#  - Table:
# |  | Area |
# | --- | --- |
# | 10 | 314.159265 |
# | 20 | 1,256.637061 |
# | 30 | 2,827.433388 |
